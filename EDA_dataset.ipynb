# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
df = pd.read_csv("sample_fr_en_clean.csv")

# %%
df
# Out:
#                                                        fr  \
# 0       Vous avez cru jusqu'à ce jour qu'il y avait de...
# 1                Comment nourrissez-vous votre famille ?"
# 2       Le premier ciel est une voûte à laquelle la te...
# 3       Il est dit après cela, qu'il s'est divisé en m...
# 4       Ils sont serviles à son égard, et créés pour u...
# ...                                                   ...
# 199332  Le village a été d'abord mentionné en 1326 com...
# 199333  L'organisation soutient les femmes qui souhait...
# 199334  Pendant les 10 années suivantes, l'Orchestre d...
# 199335  En 1546, il prend le gouvernement du comté de ...
# 199336  La Chine est alors devenue la quatrième agence...
#
#                                                        en
# 0        You thought to this day that there were tyrants?
# 1                           How do you feed your family?"
# 2       The first group shows God creating the Heavens...
# ...

# %%
# Aperçu des 5 premières lignes
print("📌 Aperçu du dataset :")
print(df.head())

# Infos générales
print("\n🧠 Infos générales :")
print(df.info())

# Dimensions du dataset
print(f"\n📐 Taille du dataset : {df.shape[0]} lignes, {df.shape[1]} colonnes")

# Vérification des valeurs manquantes
print("\n🔍 Valeurs manquantes par colonne :")
print(df.isnull().sum())

# Statistiques sur la longueur des phrases
df['fr_len'] = df['fr'].str.len()
df['en_len'] = df['en'].str.len()

print("\n📊 Statistiques des longueurs de phrases :")
print(df[['fr_len', 'en_len']].describe())
# Out:
# 📌 Aperçu du dataset :
#                                                   fr  \
# 0  Vous avez cru jusqu'à ce jour qu'il y avait de...
# 1           Comment nourrissez-vous votre famille ?"
# 2  Le premier ciel est une voûte à laquelle la te...
# 3  Il est dit après cela, qu'il s'est divisé en m...
# 4  Ils sont serviles à son égard, et créés pour u...
#
#                                                   en
# 0   You thought to this day that there were tyrants?
# 1                      How do you feed your family?"
# 2  The first group shows God creating the Heavens...
# 3  It is said after this he split to a thousand p...
# 4  They are subservient to him, and created for a...
#
# 🧠 Infos générales :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199337 entries, 0 to 199336
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   fr      199337 non-null  object
#  1   en      199337 non-null  object
# ...

# %%
plt.figure(figsize=(12, 5))

# Longueur phrases françaises
sns.histplot(df['fr_len'], bins=50, color='skyblue', label='Français', kde=True)

# Longueur phrases anglaises
sns.histplot(df['en_len'], bins=50, color='salmon', label='Anglais', kde=True)

plt.title("Distribution des longueurs de phrases")
plt.xlabel("Nombre de caractères")
plt.ylabel("Fréquence")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Nuage de mots - français
text_fr = ' '.join(df['fr'].tolist())
wordcloud_fr = WordCloud(width=800, height=400, background_color='white').generate(text_fr)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_fr, interpolation='bilinear')
plt.axis('off')
plt.title("Nuage de mots - Français")
plt.show()
